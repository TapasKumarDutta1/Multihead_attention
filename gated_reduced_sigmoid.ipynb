# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/Multihead_attention/blob/master/gated_reduced_sigmoid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
fnl_acc3=list(np.load('/content/final_accuracy_all_fold1_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('/content/final_accuracy_all_fold2_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('/content/final_accuracy_all_fold3_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('/content/final_accuracy_all_fold4_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('/content/final_accuracy_all_fold5_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9569815418291059

# %%
fnl_acc3=list(np.load('/content/times_all_fold_1_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('/content/times_all_fold_2_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('/content/times_all_fold_3_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('/content/times_all_fold_4_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('/content/times_all_fold_5_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 9025.286699914932

# %%
tot_ans=[]
tot_pre=[]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('/content/answers_all_fold_1_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_all_fold_1_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[112   0   0]
#  [  8 235   2]
#  [  3   5 177]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('/content/answers_all_fold_2_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_all_fold_2_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[153  12   2]
#  [  4 333   1]
#  [  6   9 159]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('/content/answers_all_fold_3_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_all_fold_3_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[134   3   2]
#  [ 18 213   0]
#  [  2   1 199]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('/content/answers_all_fold_4_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_all_fold_4_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[112   9   3]
#  [  5 320   0]
#  [  3   2 174]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('/content/answers_all_fold_5_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_all_fold_5_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[146   1  19]
#  [ 13 274   0]
#  [  0   0 190]]

# %%
import seaborn as sns
from matplotlib import pyplot as plt
sns.heatmap(confusion_matrix(tot_ans,tot_pre),annot=True,cmap='Blues', fmt='g',xticklabels=['Meningioma', 'Glioma','Pituitary' ],yticklabels=['Meningioma', 'Glioma','Pituitary' ])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig('mobilenet.png')

# %%
history={}
history['fold1']=np.load('/content/history_all_fold_1_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item()
history['fold2']=np.load('/content/history_all_fold_2_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item()
history['fold3']=np.load('/content/history_all_fold_3_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item()
history['fold4']=np.load('/content/history_all_fold_4_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item()
history['fold5']=np.load('/content/history_all_fold_5_final_gated_reduced_max_sigmoid_.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
