# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/Multihead_attention/blob/master/resnet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
fnl_acc3=list(np.load('/content/final_accuracy_last_fold1_1e-4_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('/content/final_accuracy_last_fold2_1e-4_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('/content/final_accuracy_all_fold3_final_final_3535.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('/content/final_accuracy_last_fold4_1e-4_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('/content/final_accuracy_last_fold5_1e-4_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9612106390666748

# %%
fnl_acc3=list(np.load('/content/times_all_fold_3_final_final_3535.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('/content/times_last_fold4_1e-4_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('/content/times_last_fold5_1e-4_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('/content/times_last_fold2_1e-4_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('/content/times_last_fold1_1e-4_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 6937.99352054596

# %%
tot_ans=[]
tot_pre=[]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('/content/answers_last_fold1_1e-4_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_last_fold1_1e-4_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[109   3   0]
#  [  1 243   1]
#  [  9   3 173]]

# %%
ans_1=np.load('/content/answers_last_fold2_1e-4_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_last_fold2_1e-4_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[150  14   3]
#  [  7 330   1]
#  [  3   5 166]]

# %%
ans_1=np.load('/content/answers_all_fold_3_final_final_3535.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_all_fold_3_final_final_3535.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[129   8   2]
#  [ 13 218   0]
#  [  1   0 201]]

# %%
ans_1=np.load('/content/answers_last_fold4_1e-4_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_last_fold4_1e-4_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[117   5   2]
#  [  0 325   0]
#  [  6   0 173]]

# %%
ans_1=np.load('/content/answers_last_fold5_1e-4_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_last_fold5_1e-4_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[143   2  21]
#  [  7 279   1]
#  [  0   2 188]]

# %%
import seaborn as sns
from matplotlib import pyplot as plt
sns.heatmap(confusion_matrix(tot_ans,tot_pre),annot=True,cmap='Blues', fmt='g',xticklabels=['Meningioma', 'Glioma','Pituitary' ],yticklabels=['Meningioma', 'Glioma','Pituitary' ])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig('mobilenet.png')

# %%
history={}
history['fold1']=np.load('/content/history_last_fold1_1e-4_wn.npy',allow_pickle=True).item()
history['fold2']=np.load('/content/history_last_fold2_1e-4_wn.npy',allow_pickle=True).item()
history['fold3']=np.load('/content/history_all_fold_3_final_final_3535.npy',allow_pickle=True).item()
history['fold4']=np.load('/content/history_last_fold4_1e-4_wn.npy',allow_pickle=True).item()
history['fold5']=np.load('/content/history_last_fold5_1e-4_wn.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
