# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/Multihead_attention/blob/master/squeezenet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
fnl_acc3=list(np.load('/content/final_accuracy_all_fold3_xception_squeezenet_.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('/content/final_accuracy_all_fold5_xception_squeezenet_.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('/content/final_accuracy_all_fold4_xception_squeezenet_.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('/content/final_accuracy_all_fold2_xception_squeezenet_.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('/content/final_accuracy_all_fold1_xception_squeezenet_.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.93263999241389

# %%
fnl_acc3=list(np.load('/content/times_all_fold_3_xception_squeezenet_.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('/content/times_all_fold_4_xception_squeezenet_.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('/content/times_all_fold_5_xception_squeezenet_.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('/content/times_all_fold_2_xception_squeezenet_.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('/content/times_all_fold_1_xception_squeezenet_.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 2708.777389574051

# %%
tot_ans=[]
tot_pre=[]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('/content/answers_all_fold_1_xception_squeezenet_.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_all_fold_1_xception_squeezenet_.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[107   4   1]
#  [ 19 224   2]
#  [ 17   0 168]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('/content/answers_all_fold_2_xception_squeezenet_.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_all_fold_2_xception_squeezenet_.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[141  19   7]
#  [ 20 312   6]
#  [ 12   2 160]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('/content/answers_all_fold_3_xception_squeezenet_.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_all_fold_3_xception_squeezenet_.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[134   3   2]
#  [ 20 211   0]
#  [  3   0 199]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('/content/answers_all_fold_4_xception_squeezenet_.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_all_fold_4_xception_squeezenet_.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[115   4   5]
#  [  8 317   0]
#  [  7   0 172]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('/content/answers_all_fold_5_xception_squeezenet_.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_all_fold_5_xception_squeezenet_.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[137   8  21]
#  [ 13 273   1]
#  [  1   3 186]]

# %%
import seaborn as sns
from matplotlib import pyplot as plt
sns.heatmap(confusion_matrix(tot_ans,tot_pre),annot=True,cmap='Blues', fmt='g',xticklabels=['Meningioma', 'Glioma','Pituitary' ],yticklabels=['Meningioma', 'Glioma','Pituitary' ])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig('mobilenet.png')

# %%
history={}
history['fold1']=np.load('/content/history_all_fold_1_xception_squeezenet_.npy',allow_pickle=True).item()
history['fold2']=np.load('/content/history_all_fold_2_xception_squeezenet_.npy',allow_pickle=True).item()
history['fold3']=np.load('/content/history_all_fold_3_xception_squeezenet_.npy',allow_pickle=True).item()
history['fold4']=np.load('/content/history_all_fold_4_xception_squeezenet_.npy',allow_pickle=True).item()
history['fold5']=np.load('/content/history_all_fold_5_xception_squeezenet_.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
